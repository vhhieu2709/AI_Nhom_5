# %% [markdown]
# # 🤟 So sánh Model A vs Model B — ASL Recognition
#
# | | Model A (Baseline) | Model B (Cải tiến) |
# |--|--|--|
# | **Data** | 650 ảnh/lớp | 650 ảnh/lớp |
# | **Augmentation** | Nhẹ (rotation, shift, zoom) | Mạnh (+ brightness, contrast, noise) |
# | **Loss** | Categorical Crossentropy | Label Smoothing (0.1) |
# | **Dropout** | 0.4 | 0.5 + thêm 1 layer |
# | **Architecture** | MobileNetV2 + head đơn giản | MobileNetV2 + head sâu hơn |
#
# > ⚠️ **Trước khi chạy:** Runtime → Change runtime type → GPU (T4)

# %% [markdown]
# ---
# # PHẦN 1: SETUP

# %%
# ============================================================
# BƯỚC 1.1 — Kết nối Drive + cài thư viện
# ============================================================
from google.colab import drive
drive.mount('/content/drive')

# !pip install -q scikit-learn seaborn

import tensorflow as tf
import numpy as np
import os, zipfile, shutil
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras import layers, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

print(f'✅ TensorFlow: {tf.__version__}')
print(f'✅ GPU: {tf.config.list_physical_devices("GPU")}')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ TensorFlow: 2.20.0
# ✅ GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# BƯỚC 1.2 — Giải nén (giữ nguyên cấu trúc có sẵn)
ZIP_PATH   = '/content/drive/MyDrive/AI/asl_split.zip'
EXTRACT_TO = '/content/asl_raw'
SEED       = 42

if os.path.exists(EXTRACT_TO):
    shutil.rmtree(EXTRACT_TO)

print('📦 Đang giải nén...')
with zipfile.ZipFile(ZIP_PATH, 'r') as z:
    z.extractall(EXTRACT_TO)
print('✅ Giải nén xong!')

# DATA_DIR trỏ thẳng vào thư mục đã có sẵn train/val/test
DATA_DIR = '/content/asl_raw/asl_split'

# Lấy danh sách lớp từ thư mục train (bỏ qua file .csv)
classes = sorted([
    d for d in os.listdir(os.path.join(DATA_DIR, 'train'))
    if os.path.isdir(os.path.join(DATA_DIR, 'train', d))
])

print(f'\n🔤 Số lớp: {len(classes)} → {classes}')
for split in ['train', 'val', 'test']:
    total = sum(len(os.listdir(os.path.join(DATA_DIR, split, c))) for c in classes)
    print(f'  {split}: {total} ảnh')

print('\n✅ Dữ liệu đã chia sẵn')
# Out:
# 📦 Đang giải nén...
# ✅ Giải nén xong!
#
# 🔤 Số lớp: 28 → ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'M', 'N', 'Nothing', 'O', 'P', 'Q', 'R', 'S', 'Space', 'T', 'U', 'V', 'W', 'X', 'Y', 'Z']
#   train: 12232 ảnh
#   val: 2614 ảnh
#   test: 2654 ảnh
#
# ✅ Dữ liệu đã chia sẵn

# %%
# ============================================================
# BƯỚC 1.3 — Tiền xử lý CLAHE toàn bộ dataset
#
# [Kỹ thuật chưa học trên lớp]
# CLAHE (Contrast Limited Adaptive Histogram Equalization):
#   - Tăng tương phản cục bộ trên kênh L của không gian LAB
#   - clipLimit=2.0: giới hạn khuếch đại tương phản
#   - tileGridSize=(8,8): chia ảnh thành 64 ô nhỏ xử lý độc lập
#
# Lý do dùng:
#   Dataset tự chụp có ánh sáng không đồng đều
#   → CLAHE giúp model nhìn rõ đường nét ngón tay hơn
# ============================================================
import cv2

def apply_clahe(img_bgr):
    lab     = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe   = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    l_eq    = clahe.apply(l)
    lab_eq  = cv2.merge([l_eq, a, b])
    return cv2.cvtColor(lab_eq, cv2.COLOR_LAB2BGR)

def apply_clahe_to_folder(data_dir, classes):
    total = 0
    for split in ['train', 'val', 'test']:
        print(f'  Đang xử lý {split}...')
        for cls in classes:
            cls_path = os.path.join(data_dir, split, cls)
            if not os.path.isdir(cls_path):
                continue
            for img_name in os.listdir(cls_path):
                if not img_name.lower().endswith(('.jpg','.jpeg','.png')):
                    continue
                img_path = os.path.join(cls_path, img_name)
                img = cv2.imread(img_path)
                if img is not None:
                    cv2.imwrite(img_path, apply_clahe(img))
                    total += 1
    return total

print('🔧 Đang áp dụng CLAHE...')
total = apply_clahe_to_folder(DATA_DIR, classes)
print(f'✅ Xong! Đã xử lý {total} ảnh')
# Out:
# 🔧 Đang áp dụng CLAHE...
#   Đang xử lý train...
#   Đang xử lý val...
#   Đang xử lý test...
# ✅ Xong! Đã xử lý 17500 ảnh

# %% [markdown]
# ---
# # PHẦN 2: MODEL A — BASELINE (650 ảnh, augmentation nhẹ)

# %%
# ============================================================
# BƯỚC 2.1 — Cấu hình Model A
#
# Giữ nguyên như model cũ, chỉ đổi data mới (650 ảnh)
# Augmentation nhẹ: rotation, shift, zoom, horizontal_flip=False
# Loss: Categorical Crossentropy thường
# Dropout: 0.4
# ============================================================
IMG_SIZE   = (224, 224)
BATCH_SIZE = 32

# Augmentation nhẹ (giống model cũ)
train_datagen_A = ImageDataGenerator(
    rescale=1./255,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=False
)
val_test_datagen = ImageDataGenerator(rescale=1./255)

train_A = train_datagen_A.flow_from_directory(
    f'{DATA_DIR}/train', target_size=IMG_SIZE,
    batch_size=BATCH_SIZE, class_mode='categorical',
    shuffle=True, seed=SEED
)
val_A = val_test_datagen.flow_from_directory(
    f'{DATA_DIR}/val', target_size=IMG_SIZE,
    batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False
)
test_A = val_test_datagen.flow_from_directory(
    f'{DATA_DIR}/test', target_size=IMG_SIZE,
    batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False
)

CLASS_NAMES = list(train_A.class_indices.keys())
NUM_CLASSES = len(CLASS_NAMES)
print(f'✅ Số lớp: {NUM_CLASSES}')
print(f'   Train: {train_A.samples} | Val: {val_A.samples} | Test: {test_A.samples}')
# Out:
# Found 12232 images belonging to 28 classes.
# Found 2614 images belonging to 28 classes.
# Found 2654 images belonging to 28 classes.
# ✅ Số lớp: 28
#    Train: 12232 | Val: 2614 | Test: 2654

# %%
# ============================================================
# BƯỚC 2.2 — Xây dựng Model A
#
# Kiến trúc giống model cũ:
#   MobileNetV2 (freeze) → GlobalAvgPool → BN → Dense(256) → Dropout(0.4) → Output
# ============================================================
def build_model_A(num_classes):
    base = MobileNetV2(input_shape=(*IMG_SIZE, 3), include_top=False, weights='imagenet')
    base.trainable = False

    inputs = tf.keras.Input(shape=(*IMG_SIZE, 3))
    x = base(inputs, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.4)(x)               # Dropout nhẹ hơn
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    return Model(inputs, outputs)

model_A = build_model_A(NUM_CLASSES)

# Loss thường (không label smoothing)
model_A.compile(
    optimizer=Adam(learning_rate=1e-3),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
print('✅ Model A đã sẵn sàng!')
print(f'   Tham số trainable: {sum(tf.size(w).numpy() for w in model_A.trainable_weights):,}')
# Out:
# ✅ Model A đã sẵn sàng!
#    Tham số trainable: 337,692

# %%
# ============================================================
# BƯỚC 2.3 — Train Model A Giai đoạn 1 (Freeze base)
# ⏱️ Ước tính: 10-15 phút
# ============================================================
callbacks_A1 = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    ModelCheckpoint('/content/drive/MyDrive/AI/model_A_phase1.keras',
                    monitor='val_accuracy', save_best_only=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)
]

print('🚀 Train Model A — Giai đoạn 1 (Freeze base)...')
history_A1 = model_A.fit(
    train_A, epochs=15, validation_data=val_A,
    callbacks=callbacks_A1, verbose=1
)
print('✅ Giai đoạn 1 xong!')
# Out:
# 🚀 Train Model A — Giai đoạn 1 (Freeze base)...
# Epoch 1/15
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.7603 - loss: 0.8947
# Epoch 1: val_accuracy improved from None to 0.98125, saving model to /content/drive/MyDrive/AI/model_A_phase1.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/AI/model_A_phase1.keras
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 191s 445ms/step - accuracy: 0.8788 - loss: 0.4196 - val_accuracy: 0.9813 - val_loss: 0.0696 - learning_rate: 0.0010
# Epoch 2/15
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step - accuracy: 0.9652 - loss: 0.1171
# Epoch 2: val_accuracy improved from 0.98125 to 0.98278, saving model to /content/drive/MyDrive/AI/model_A_phase1.keras
#
# Epoch 2: finished saving model to /content/drive/MyDrive/AI/model_A_phase1.keras
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 156s 406ms/step - accuracy: 0.9639 - loss: 0.1136 - val_accuracy: 0.9828 - val_loss: 0.0460 - learning_rate: 0.0010
# Epoch 3/15
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.9687 - loss: 0.0933
# Epoch 3: val_accuracy improved from 0.98278 to 0.98661, saving model to /content/drive/MyDrive/AI/model_A_phase1.keras
#
# Epoch 3: finished saving model to /content/drive/MyDrive/AI/model_A_phase1.keras
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 155s 406ms/step - accuracy: 0.9691 - loss: 0.0934 - val_accuracy: 0.9866 - val_loss: 0.0467 - learning_rate: 0.0010
# Epoch 4/15
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - accuracy: 0.9786 - loss: 0.0684
# Epoch 4: val_accuracy improved from 0.98661 to 0.98929, saving model to /content/drive/MyDrive/AI/model_A_phase1.keras
#
# Epoch 4: finished saving model to /content/drive/MyDrive/AI/model_A_phase1.keras
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 154s 402ms/step - accuracy: 0.9778 - loss: 0.0705 - val_accuracy: 0.9893 - val_loss: 0.0342 - learning_rate: 0.0010
# Epoch 5/15
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9764 - loss: 0.0675
# Epoch 5: val_accuracy improved from 0.98929 to 0.99158, saving model to /content/drive/MyDrive/AI/model_A_phase1.keras
#
# Epoch 5: finished saving model to /content/drive/MyDrive/AI/model_A_phase1.keras
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 156s 408ms/step - accuracy: 0.9783 - loss: 0.0664 - val_accuracy: 0.9916 - val_loss: 0.0369 - learning_rate: 0.0010
# Epoch 6/15
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.9798 - loss: 0.0614
# Epoch 6: val_accuracy improved from 0.99158 to 0.99388, saving model to /content/drive/MyDrive/AI/model_A_phase1.keras
#
# Epoch 6: finished saving model to /content/drive/MyDrive/AI/model_A_phase1.keras
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 156s 408ms/step - accuracy: 0.9789 - loss: 0.0655 - val_accuracy: 0.9939 - val_loss: 0.0285 - learning_rate: 0.0010
# Epoch 7/15
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.9812 - loss: 0.0632
# Epoch 7: val_accuracy did not improve from 0.99388
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 156s 407ms/step - accuracy: 0.9813 - loss: 0.0661 - val_accuracy: 0.9908 - val_loss: 0.0362 - learning_rate: 0.0010
# Epoch 8/15
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.9862 - loss: 0.0477
# Epoch 8: val_accuracy did not improve from 0.99388
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 158s 412ms/step - accuracy: 0.9832 - loss: 0.0542 - val_accuracy: 0.9931 - val_loss: 0.0372 - learning_rate: 0.0010
# Epoch 9/15
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9799 - loss: 0.0721
# Epoch 9: val_accuracy did not improve from 0.99388
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 156s 406ms/step - accuracy: 0.9803 - loss: 0.0730 - val_accuracy: 0.9897 - val_loss: 0.0382 - learning_rate: 0.0010
# Epoch 10/15
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.9854 - loss: 0.0538
# Epoch 10: val_accuracy improved from 0.99388 to 0.99656, saving model to /content/drive/MyDrive/AI/model_A_phase1.keras
#
# Epoch 10: finished saving model to /content/drive/MyDrive/AI/model_A_phase1.keras
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 154s 403ms/step - accuracy: 0.9882 - loss: 0.0398 - val_accuracy: 0.9966 - val_loss: 0.0164 - learning_rate: 5.0000e-04
# Epoch 11/15
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.9900 - loss: 0.0272
# Epoch 11: val_accuracy improved from 0.99656 to 0.99694, saving model to /content/drive/MyDrive/AI/model_A_phase1.keras
#
# Epoch 11: finished saving model to /content/drive/MyDrive/AI/model_A_phase1.keras
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 155s 405ms/step - accuracy: 0.9894 - loss: 0.0318 - val_accuracy: 0.9969 - val_loss: 0.0197 - learning_rate: 5.0000e-04
# Epoch 12/15
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9921 - loss: 0.0323
# Epoch 12: val_accuracy improved from 0.99694 to 0.99809, saving model to /content/drive/MyDrive/AI/model_A_phase1.keras
#
# Epoch 12: finished saving model to /content/drive/MyDrive/AI/model_A_phase1.keras
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 155s 405ms/step - accuracy: 0.9918 - loss: 0.0302 - val_accuracy: 0.9981 - val_loss: 0.0143 - learning_rate: 5.0000e-04
# Epoch 13/15
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.9925 - loss: 0.0213
# Epoch 13: val_accuracy did not improve from 0.99809
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 204s 411ms/step - accuracy: 0.9927 - loss: 0.0213 - val_accuracy: 0.9973 - val_loss: 0.0146 - learning_rate: 5.0000e-04
# Epoch 14/15
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.9931 - loss: 0.0198
# Epoch 14: val_accuracy did not improve from 0.99809
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 156s 407ms/step - accuracy: 0.9925 - loss: 0.0207 - val_accuracy: 0.9969 - val_loss: 0.0186 - learning_rate: 5.0000e-04
# Epoch 15/15
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.9931 - loss: 0.0192
# Epoch 15: val_accuracy did not improve from 0.99809
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 158s 411ms/step - accuracy: 0.9921 - loss: 0.0216 - val_accuracy: 0.9977 - val_loss: 0.0093 - learning_rate: 5.0000e-04
# ✅ Giai đoạn 1 xong!

# %%
# ============================================================
# BƯỚC 2.4 — Fine-tune Model A Giai đoạn 2 (Unfreeze 30 layer)
# ⏱️ Ước tính: 10-15 phút
# ============================================================
base_A = model_A.layers[1]
base_A.trainable = True
fine_tune_at = len(base_A.layers) - 30
for layer in base_A.layers[:fine_tune_at]:
    layer.trainable = False

model_A.compile(
    optimizer=Adam(learning_rate=1e-5),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

callbacks_A2 = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    ModelCheckpoint('/content/drive/MyDrive/AI/model_A_final.keras',
                    monitor='val_accuracy', save_best_only=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-7)
]

print('🚀 Train Model A — Giai đoạn 2 (Fine-tune)...')
history_A2 = model_A.fit(
    train_A, epochs=10, validation_data=val_A,
    callbacks=callbacks_A2, verbose=1
)
print('✅ Model A hoàn thành!')
# Out:
# 🚀 Train Model A — Giai đoạn 2 (Fine-tune)...
# Epoch 1/10
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.9110 - loss: 0.3351
# Epoch 1: val_accuracy improved from None to 0.99235, saving model to /content/drive/MyDrive/AI/model_A_final.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/AI/model_A_final.keras
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 195s 461ms/step - accuracy: 0.9318 - loss: 0.2430 - val_accuracy: 0.9923 - val_loss: 0.0263 - learning_rate: 1.0000e-05
# Epoch 2/10
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.9623 - loss: 0.1318
# Epoch 2: val_accuracy improved from 0.99235 to 0.99694, saving model to /content/drive/MyDrive/AI/model_A_final.keras
#
# Epoch 2: finished saving model to /content/drive/MyDrive/AI/model_A_final.keras
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 158s 412ms/step - accuracy: 0.9667 - loss: 0.1152 - val_accuracy: 0.9969 - val_loss: 0.0122 - learning_rate: 1.0000e-05
# Epoch 3/10
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.9737 - loss: 0.0708
# Epoch 3: val_accuracy did not improve from 0.99694
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 160s 417ms/step - accuracy: 0.9756 - loss: 0.0720 - val_accuracy: 0.9966 - val_loss: 0.0115 - learning_rate: 1.0000e-05
# Epoch 4/10
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - accuracy: 0.9786 - loss: 0.0618
# Epoch 4: val_accuracy did not improve from 0.99694
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 159s 415ms/step - accuracy: 0.9822 - loss: 0.0557 - val_accuracy: 0.9962 - val_loss: 0.0099 - learning_rate: 1.0000e-05
# Epoch 5/10
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.9844 - loss: 0.0491
# Epoch 5: val_accuracy improved from 0.99694 to 0.99732, saving model to /content/drive/MyDrive/AI/model_A_final.keras
#
# Epoch 5: finished saving model to /content/drive/MyDrive/AI/model_A_final.keras
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 160s 417ms/step - accuracy: 0.9859 - loss: 0.0445 - val_accuracy: 0.9973 - val_loss: 0.0110 - learning_rate: 1.0000e-05
# Epoch 6/10
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9861 - loss: 0.0399
# Epoch 6: val_accuracy did not improve from 0.99732
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 156s 407ms/step - accuracy: 0.9877 - loss: 0.0350 - val_accuracy: 0.9973 - val_loss: 0.0104 - learning_rate: 1.0000e-05
# Epoch 7/10
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.9885 - loss: 0.0346
# Epoch 7: val_accuracy did not improve from 0.99732
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 157s 411ms/step - accuracy: 0.9886 - loss: 0.0329 - val_accuracy: 0.9973 - val_loss: 0.0114 - learning_rate: 1.0000e-05
# Epoch 8/10
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.9928 - loss: 0.0217
# Epoch 8: val_accuracy did not improve from 0.99732
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 157s 411ms/step - accuracy: 0.9922 - loss: 0.0219 - val_accuracy: 0.9969 - val_loss: 0.0114 - learning_rate: 5.0000e-06
# Epoch 9/10
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.9914 - loss: 0.0232
# Epoch 9: val_accuracy did not improve from 0.99732
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 159s 416ms/step - accuracy: 0.9919 - loss: 0.0226 - val_accuracy: 0.9973 - val_loss: 0.0115 - learning_rate: 5.0000e-06
# ✅ Model A hoàn thành!

# %%
# ============================================================
# BƯỚC 2.5 — Đánh giá Model A trên tập Test
# ============================================================
print('🔍 Đánh giá Model A...')
model_A_best = tf.keras.models.load_model('/content/drive/MyDrive/AI/model_A_final.keras')

y_pred_A = np.argmax(model_A_best.predict(test_A, verbose=1), axis=1)
y_true   = test_A.classes

acc_A    = np.mean(y_pred_A == y_true)
report_A = classification_report(y_true, y_pred_A, target_names=CLASS_NAMES, output_dict=True)
cm_A     = confusion_matrix(y_true, y_pred_A)

print(f'\n📊 Model A — Test Accuracy: {acc_A*100:.2f}%')
print(f'   Macro F1  : {report_A["macro avg"]["f1-score"]*100:.2f}%')
print(f'   Precision : {report_A["macro avg"]["precision"]*100:.2f}%')
print(f'   Recall    : {report_A["macro avg"]["recall"]*100:.2f}%')

# Lưu report
report_A_str = classification_report(y_true, y_pred_A, target_names=CLASS_NAMES)
with open('/content/drive/MyDrive/AI/report_model_A.txt', 'w') as f:
    f.write(f'Test Accuracy: {acc_A:.4f}\n\n{report_A_str}')
print('✅ Đã lưu report Model A!')
# Out:
# 🔍 Đánh giá Model A...
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 14s 96ms/step
#
# 📊 Model A — Test Accuracy: 99.81%
#    Macro F1  : 99.82%
#    Precision : 99.82%
#    Recall    : 99.82%
# ✅ Đã lưu report Model A!

# %% [markdown]
# ---
# # PHẦN 3: MODEL B — CẢI TIẾN (Augmentation mạnh + Label Smoothing + Dropout mạnh hơn)

# %%
# ============================================================
# BƯỚC 3.1 — Cấu hình Model B
#
# Cải tiến so với Model A:
#
# [Chưa học trên lớp]
# 1. Augmentation mạnh hơn:
#    + brightness_range: thay đổi độ sáng [0.6, 1.4]
#      → Giúp model quen với nhiều điều kiện ánh sáng
#    + shear_range: biến dạng góc nghiêng
#      → Giúp model nhận diện tay ở góc hơi nghiêng
#    + channel_shift_range: thay đổi màu sắc
#      → Giúp model không bị phụ thuộc vào màu da cố định
#
# 2. Label Smoothing (0.1):
#    → Thay vì nhãn cứng [0,0,1,0,...], làm mềm thành [0.003, 0.003, 0.91, 0.003,...]
#    → Phạt sự tự tin thái quá (overconfidence)
#    → Giảm overfitting, cải thiện tổng quát hóa
#
# 3. Dropout mạnh hơn (0.5) + thêm 1 Dense layer:
#    → Tắt 50% neuron ngẫu nhiên mỗi batch
#    → Buộc model học đặc trưng phân tán, không phụ thuộc neuron cụ thể
# ============================================================

# Augmentation MẠNH cho Model B
train_datagen_B = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,           # xoay nhiều hơn (15 thay vì 10)
    width_shift_range=0.15,      # dịch chuyển nhiều hơn
    height_shift_range=0.15,
    zoom_range=0.15,
    shear_range=0.1,             # ← MỚI: biến dạng góc nghiêng
    brightness_range=[0.6, 1.4], # ← MỚI: thay đổi độ sáng mạnh
    channel_shift_range=20.0,    # ← MỚI: thay đổi màu sắc
    horizontal_flip=False        # KHÔNG lật ngang (ký hiệu tay phân biệt trái/phải)
)

train_B = train_datagen_B.flow_from_directory(
    f'{DATA_DIR}/train', target_size=IMG_SIZE,
    batch_size=BATCH_SIZE, class_mode='categorical',
    shuffle=True, seed=SEED
)
# Val và Test dùng chung datagen không augmentation
val_B  = val_test_datagen.flow_from_directory(
    f'{DATA_DIR}/val', target_size=IMG_SIZE,
    batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False
)
test_B = val_test_datagen.flow_from_directory(
    f'{DATA_DIR}/test', target_size=IMG_SIZE,
    batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False
)
print('✅ Data generators Model B sẵn sàng!')
# Out:
# Found 12232 images belonging to 28 classes.
# Found 2614 images belonging to 28 classes.
# Found 2654 images belonging to 28 classes.
# ✅ Data generators Model B sẵn sàng!

# %%
# ============================================================
# BƯỚC 3.2 — Xây dựng Model B
#
# Kiến trúc head sâu hơn:
#   MobileNetV2 → GlobalAvgPool → BN
#   → Dense(512) → Dropout(0.5)
#   → Dense(256) → Dropout(0.3)   ← thêm 1 layer
#   → Output(softmax)
# ============================================================
def build_model_B(num_classes):
    base = MobileNetV2(input_shape=(*IMG_SIZE, 3), include_top=False, weights='imagenet')
    base.trainable = False

    inputs = tf.keras.Input(shape=(*IMG_SIZE, 3))
    x = base(inputs, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dense(512, activation='relu')(x)   # lớn hơn Model A
    x = layers.Dropout(0.5)(x)                    # Dropout mạnh hơn
    x = layers.Dense(256, activation='relu')(x)   # thêm 1 Dense layer
    x = layers.Dropout(0.3)(x)                    # Dropout thứ 2
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    return Model(inputs, outputs)

model_B = build_model_B(NUM_CLASSES)

# Label Smoothing: làm mềm nhãn → giảm overconfidence
model_B.compile(
    optimizer=Adam(learning_rate=1e-3),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy']
)
print('✅ Model B đã sẵn sàng!')
print(f'   Tham số trainable: {sum(tf.size(w).numpy() for w in model_B.trainable_weights):,}')
# Out:
# ✅ Model B đã sẵn sàng!
#    Tham số trainable: 796,956

# %%
# ============================================================
# BƯỚC 3.3 — Train Model B Giai đoạn 1
# ⏱️ Ước tính: 10-15 phút
# ============================================================
callbacks_B1 = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    ModelCheckpoint('/content/drive/MyDrive/AI/model_B_phase1.keras',
                    monitor='val_accuracy', save_best_only=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)
]

print('🚀 Train Model B — Giai đoạn 1 (Freeze base)...')
history_B1 = model_B.fit(
    train_B, epochs=15, validation_data=val_B,
    callbacks=callbacks_B1, verbose=1
)
print('✅ Giai đoạn 1 xong!')
# Out:
# 🚀 Train Model B — Giai đoạn 1 (Freeze base)...
# Epoch 1/15
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step - accuracy: 0.6232 - loss: 1.8930
# Epoch 1: val_accuracy improved from None to 0.95256, saving model to /content/drive/MyDrive/AI/model_B_phase1.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/AI/model_B_phase1.keras
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 212s 523ms/step - accuracy: 0.7622 - loss: 1.4629 - val_accuracy: 0.9526 - val_loss: 0.8941 - learning_rate: 0.0010
# Epoch 2/15
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step - accuracy: 0.8829 - loss: 1.1237
# Epoch 2: val_accuracy improved from 0.95256 to 0.97322, saving model to /content/drive/MyDrive/AI/model_B_phase1.keras
#
# Epoch 2: finished saving model to /content/drive/MyDrive/AI/model_B_phase1.keras
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 185s 484ms/step - accuracy: 0.8940 - loss: 1.0974 - val_accuracy: 0.9732 - val_loss: 0.8283 - learning_rate: 0.0010
# Epoch 3/15
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - accuracy: 0.9195 - loss: 1.0265
# Epoch 3: val_accuracy improved from 0.97322 to 0.98317, saving model to /content/drive/MyDrive/AI/model_B_phase1.keras
#
# Epoch 3: finished saving model to /content/drive/MyDrive/AI/model_B_phase1.keras
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 179s 466ms/step - accuracy: 0.9242 - loss: 1.0150 - val_accuracy: 0.9832 - val_loss: 0.7772 - learning_rate: 0.0010
# Epoch 4/15
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 0.9374 - loss: 0.9789
# Epoch 4: val_accuracy improved from 0.98317 to 0.99005, saving model to /content/drive/MyDrive/AI/model_B_phase1.keras
#
# Epoch 4: finished saving model to /content/drive/MyDrive/AI/model_B_phase1.keras
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 182s 475ms/step - accuracy: 0.9400 - loss: 0.9701 - val_accuracy: 0.9901 - val_loss: 0.7561 - learning_rate: 0.0010
# Epoch 5/15
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step - accuracy: 0.9492 - loss: 0.9344
# Epoch 5: val_accuracy improved from 0.99005 to 0.99120, saving model to /content/drive/MyDrive/AI/model_B_phase1.keras
#
# Epoch 5: finished saving model to /content/drive/MyDrive/AI/model_B_phase1.keras
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 185s 484ms/step - accuracy: 0.9518 - loss: 0.9260 - val_accuracy: 0.9912 - val_loss: 0.7405 - learning_rate: 0.0010
# Epoch 6/15
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step - accuracy: 0.9569 - loss: 0.9108
# Epoch 6: val_accuracy did not improve from 0.99120
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 184s 480ms/step - accuracy: 0.9595 - loss: 0.9052 - val_accuracy: 0.9908 - val_loss: 0.7547 - learning_rate: 0.0010
# Epoch 7/15
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - accuracy: 0.9619 - loss: 0.8900
# Epoch 7: val_accuracy did not improve from 0.99120
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 178s 464ms/step - accuracy: 0.9635 - loss: 0.8883 - val_accuracy: 0.9912 - val_loss: 0.7409 - learning_rate: 0.0010
# Epoch 8/15
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - accuracy: 0.9705 - loss: 0.8752
# Epoch 8: val_accuracy improved from 0.99120 to 0.99311, saving model to /content/drive/MyDrive/AI/model_B_phase1.keras
#
# Epoch 8: finished saving model to /content/drive/MyDrive/AI/model_B_phase1.keras
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 183s 479ms/step - accuracy: 0.9695 - loss: 0.8707 - val_accuracy: 0.9931 - val_loss: 0.7342 - learning_rate: 0.0010
# Epoch 9/15
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step - accuracy: 0.9701 - loss: 0.8653
# Epoch 9: val_accuracy improved from 0.99311 to 0.99350, saving model to /content/drive/MyDrive/AI/model_B_phase1.keras
#
# Epoch 9: finished saving model to /content/drive/MyDrive/AI/model_B_phase1.keras
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 180s 471ms/step - accuracy: 0.9692 - loss: 0.8689 - val_accuracy: 0.9935 - val_loss: 0.7407 - learning_rate: 0.0010
# Epoch 10/15
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - accuracy: 0.9721 - loss: 0.8622
# Epoch 10: val_accuracy improved from 0.99350 to 0.99426, saving model to /content/drive/MyDrive/AI/model_B_phase1.keras
#
# Epoch 10: finished saving model to /content/drive/MyDrive/AI/model_B_phase1.keras
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 182s 474ms/step - accuracy: 0.9713 - loss: 0.8610 - val_accuracy: 0.9943 - val_loss: 0.7253 - learning_rate: 0.0010
# Epoch 11/15
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.9749 - loss: 0.8510
# Epoch 11: val_accuracy did not improve from 0.99426
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 181s 473ms/step - accuracy: 0.9720 - loss: 0.8543 - val_accuracy: 0.9943 - val_loss: 0.7206 - learning_rate: 0.0010
# Epoch 12/15
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.9735 - loss: 0.8512
# Epoch 12: val_accuracy improved from 0.99426 to 0.99464, saving model to /content/drive/MyDrive/AI/model_B_phase1.keras
#
# Epoch 12: finished saving model to /content/drive/MyDrive/AI/model_B_phase1.keras
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 183s 477ms/step - accuracy: 0.9738 - loss: 0.8509 - val_accuracy: 0.9946 - val_loss: 0.7243 - learning_rate: 0.0010
# Epoch 13/15
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step - accuracy: 0.9770 - loss: 0.8484
# Epoch 13: val_accuracy improved from 0.99464 to 0.99541, saving model to /content/drive/MyDrive/AI/model_B_phase1.keras
#
# Epoch 13: finished saving model to /content/drive/MyDrive/AI/model_B_phase1.keras
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 200s 473ms/step - accuracy: 0.9776 - loss: 0.8460 - val_accuracy: 0.9954 - val_loss: 0.7209 - learning_rate: 0.0010
# Epoch 14/15
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step - accuracy: 0.9789 - loss: 0.8345
# Epoch 14: val_accuracy did not improve from 0.99541
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 183s 477ms/step - accuracy: 0.9783 - loss: 0.8363 - val_accuracy: 0.9943 - val_loss: 0.7221 - learning_rate: 0.0010
# Epoch 15/15
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - accuracy: 0.9804 - loss: 0.8205
# Epoch 15: val_accuracy improved from 0.99541 to 0.99770, saving model to /content/drive/MyDrive/AI/model_B_phase1.keras
#
# Epoch 15: finished saving model to /content/drive/MyDrive/AI/model_B_phase1.keras
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 179s 468ms/step - accuracy: 0.9837 - loss: 0.8092 - val_accuracy: 0.9977 - val_loss: 0.6998 - learning_rate: 5.0000e-04
# ✅ Giai đoạn 1 xong!

# %%
# ============================================================
# BƯỚC 3.4 — Fine-tune Model B Giai đoạn 2
# ⏱️ Ước tính: 10-15 phút
# ============================================================
base_B = model_B.layers[1]
base_B.trainable = True
fine_tune_at = len(base_B.layers) - 30
for layer in base_B.layers[:fine_tune_at]:
    layer.trainable = False

model_B.compile(
    optimizer=Adam(learning_rate=1e-5, clipnorm=1.0),  # thêm Gradient Clipping
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy']
)

callbacks_B2 = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    ModelCheckpoint('/content/drive/MyDrive/AI/model_B_final.keras',
                    monitor='val_accuracy', save_best_only=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-7)
]

print('🚀 Train Model B — Giai đoạn 2 (Fine-tune + Gradient Clipping)...')
history_B2 = model_B.fit(
    train_B, epochs=10, validation_data=val_B,
    callbacks=callbacks_B2, verbose=1
)
print('✅ Model B hoàn thành!')
# Out:
# 🚀 Train Model B — Giai đoạn 2 (Fine-tune + Gradient Clipping)...
# Epoch 1/10
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step - accuracy: 0.9164 - loss: 1.1117
# Epoch 1: val_accuracy improved from None to 0.99197, saving model to /content/drive/MyDrive/AI/model_B_final.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/AI/model_B_final.keras
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 226s 531ms/step - accuracy: 0.9405 - loss: 0.9879 - val_accuracy: 0.9920 - val_loss: 0.9085 - learning_rate: 1.0000e-05
# Epoch 2/10
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - accuracy: 0.9670 - loss: 0.8609
# Epoch 2: val_accuracy improved from 0.99197 to 0.99503, saving model to /content/drive/MyDrive/AI/model_B_final.keras
#
# Epoch 2: finished saving model to /content/drive/MyDrive/AI/model_B_final.keras
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 183s 479ms/step - accuracy: 0.9707 - loss: 0.8500 - val_accuracy: 0.9950 - val_loss: 0.8328 - learning_rate: 1.0000e-05
# Epoch 3/10
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step - accuracy: 0.9752 - loss: 0.8303
# Epoch 3: val_accuracy improved from 0.99503 to 0.99617, saving model to /content/drive/MyDrive/AI/model_B_final.keras
#
# Epoch 3: finished saving model to /content/drive/MyDrive/AI/model_B_final.keras
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 185s 483ms/step - accuracy: 0.9775 - loss: 0.8262 - val_accuracy: 0.9962 - val_loss: 0.7773 - learning_rate: 1.0000e-05
# Epoch 4/10
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step - accuracy: 0.9836 - loss: 0.8085
# Epoch 4: val_accuracy did not improve from 0.99617
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 204s 490ms/step - accuracy: 0.9828 - loss: 0.8110 - val_accuracy: 0.9962 - val_loss: 0.7416 - learning_rate: 1.0000e-05
# Epoch 5/10
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step - accuracy: 0.9835 - loss: 0.8061
# Epoch 5: val_accuracy improved from 0.99617 to 0.99656, saving model to /content/drive/MyDrive/AI/model_B_final.keras
#
# Epoch 5: finished saving model to /content/drive/MyDrive/AI/model_B_final.keras
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 189s 494ms/step - accuracy: 0.9852 - loss: 0.8029 - val_accuracy: 0.9966 - val_loss: 0.7236 - learning_rate: 1.0000e-05
# Epoch 6/10
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step - accuracy: 0.9863 - loss: 0.7949
# Epoch 6: val_accuracy improved from 0.99656 to 0.99732, saving model to /content/drive/MyDrive/AI/model_B_final.keras
#
# Epoch 6: finished saving model to /content/drive/MyDrive/AI/model_B_final.keras
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 184s 481ms/step - accuracy: 0.9872 - loss: 0.7928 - val_accuracy: 0.9973 - val_loss: 0.7054 - learning_rate: 1.0000e-05
# Epoch 7/10
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step - accuracy: 0.9883 - loss: 0.7900
# Epoch 7: val_accuracy did not improve from 0.99732
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 186s 486ms/step - accuracy: 0.9884 - loss: 0.7895 - val_accuracy: 0.9973 - val_loss: 0.6985 - learning_rate: 1.0000e-05
# Epoch 8/10
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step - accuracy: 0.9871 - loss: 0.7854
# Epoch 8: val_accuracy improved from 0.99732 to 0.99770, saving model to /content/drive/MyDrive/AI/model_B_final.keras
#
# Epoch 8: finished saving model to /content/drive/MyDrive/AI/model_B_final.keras
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 185s 483ms/step - accuracy: 0.9885 - loss: 0.7834 - val_accuracy: 0.9977 - val_loss: 0.6948 - learning_rate: 1.0000e-05
# Epoch 9/10
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - accuracy: 0.9906 - loss: 0.7791
# Epoch 9: val_accuracy improved from 0.99770 to 0.99809, saving model to /content/drive/MyDrive/AI/model_B_final.keras
#
# Epoch 9: finished saving model to /content/drive/MyDrive/AI/model_B_final.keras
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 183s 479ms/step - accuracy: 0.9913 - loss: 0.7765 - val_accuracy: 0.9981 - val_loss: 0.6917 - learning_rate: 1.0000e-05
# Epoch 10/10
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.9924 - loss: 0.7728
# Epoch 10: val_accuracy did not improve from 0.99809
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 182s 476ms/step - accuracy: 0.9918 - loss: 0.7713 - val_accuracy: 0.9981 - val_loss: 0.6912 - learning_rate: 1.0000e-05
# ✅ Model B hoàn thành!

# %%
# ============================================================
# BƯỚC 3.5 — Đánh giá Model B trên tập Test
# ============================================================
print('🔍 Đánh giá Model B...')
model_B_best = tf.keras.models.load_model('/content/drive/MyDrive/AI/model_B_final.keras')

y_pred_B = np.argmax(model_B_best.predict(test_B, verbose=1), axis=1)

acc_B    = np.mean(y_pred_B == y_true)
report_B = classification_report(y_true, y_pred_B, target_names=CLASS_NAMES, output_dict=True)
cm_B     = confusion_matrix(y_true, y_pred_B)

print(f'\n📊 Model B — Test Accuracy: {acc_B*100:.2f}%')
print(f'   Macro F1  : {report_B["macro avg"]["f1-score"]*100:.2f}%')
print(f'   Precision : {report_B["macro avg"]["precision"]*100:.2f}%')
print(f'   Recall    : {report_B["macro avg"]["recall"]*100:.2f}%')

report_B_str = classification_report(y_true, y_pred_B, target_names=CLASS_NAMES)
with open('/content/drive/MyDrive/AI/report_model_B.txt', 'w') as f:
    f.write(f'Test Accuracy: {acc_B:.4f}\n\n{report_B_str}')
print('✅ Đã lưu report Model B!')

# %% [markdown]
# ---
# # PHẦN 4: SO SÁNH MODEL A vs MODEL B

# %%
# ============================================================
# BƯỚC 4.1 — Bảng so sánh tổng hợp
#
# Đây là bảng quan trọng nhất cho Chương 4.2 báo cáo!
# ============================================================
print('=' * 65)
print(f'{"BẢNG SO SÁNH MODEL A vs MODEL B":^65}')
print('=' * 65)
print(f'{"Độ đo":<20} {"Model A (Baseline)":>20} {"Model B (Cải tiến)":>20}')
print('-' * 65)
print(f'{"Accuracy":<20} {acc_A*100:>19.2f}% {acc_B*100:>19.2f}%')
print(f'{"Macro F1":<20} {report_A["macro avg"]["f1-score"]*100:>19.2f}% {report_B["macro avg"]["f1-score"]*100:>19.2f}%')
print(f'{"Macro Precision":<20} {report_A["macro avg"]["precision"]*100:>19.2f}% {report_B["macro avg"]["precision"]*100:>19.2f}%')
print(f'{"Macro Recall":<20} {report_A["macro avg"]["recall"]*100:>19.2f}% {report_B["macro avg"]["recall"]*100:>19.2f}%')
print('=' * 65)

diff = (acc_B - acc_A) * 100
print(f'\n📈 Cải thiện Accuracy: {diff:+.2f}%')
if diff > 0:
    print('✅ Model B tốt hơn Model A!')
else:
    print('⚠️  Model A vẫn tốt hơn — cần điều chỉnh thêm')
# Out:
# =================================================================
#                  BẢNG SO SÁNH MODEL A vs MODEL B
# =================================================================
# Độ đo                  Model A (Baseline)   Model B (Cải tiến)
# -----------------------------------------------------------------
# Accuracy                           99.81%               99.92%
# Macro F1                           99.82%               99.93%
# Macro Precision                    99.82%               99.93%
# Macro Recall                       99.82%               99.93%
# =================================================================
#
# 📈 Cải thiện Accuracy: +0.11%
# ✅ Model B tốt hơn Model A!

# %%
# ============================================================
# BƯỚC 4.2 — Biểu đồ so sánh Training History
# ============================================================
acc_A_full     = history_A1.history['accuracy']     + history_A2.history['accuracy']
val_acc_A_full = history_A1.history['val_accuracy'] + history_A2.history['val_accuracy']
acc_B_full     = history_B1.history['accuracy']     + history_B2.history['accuracy']
val_acc_B_full = history_B1.history['val_accuracy'] + history_B2.history['val_accuracy']

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Model A
axes[0].plot(acc_A_full,     'b-', label='Train', linewidth=2)
axes[0].plot(val_acc_A_full, 'r--', label='Val',  linewidth=2)
axes[0].axvline(x=len(history_A1.history['accuracy']),
                color='gray', linestyle=':', label='Fine-tune')
axes[0].set_title('Model A — Baseline', fontsize=13, fontweight='bold')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].legend()
axes[0].grid(True, alpha=0.3)
axes[0].set_ylim([0, 1.05])

# Model B
axes[1].plot(acc_B_full,     'b-', label='Train', linewidth=2)
axes[1].plot(val_acc_B_full, 'r--', label='Val',  linewidth=2)
axes[1].axvline(x=len(history_B1.history['accuracy']),
                color='gray', linestyle=':', label='Fine-tune')
axes[1].set_title('Model B — Cải tiến', fontsize=13, fontweight='bold')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Accuracy')
axes[1].legend()
axes[1].grid(True, alpha=0.3)
axes[1].set_ylim([0, 1.05])

plt.suptitle('So sánh quá trình Training: Model A vs Model B', fontsize=14)
plt.tight_layout()
plt.savefig('/content/drive/MyDrive/AI/compare_training_history.png', dpi=150)
plt.show()
print('✅ Đã lưu biểu đồ so sánh!')

# %%
# ============================================================
# BƯỚC 4.3 — Confusion Matrix cả 2 model
# ============================================================
fig, axes = plt.subplots(1, 2, figsize=(28, 12))

for ax, cm, title, acc in [
    (axes[0], cm_A, f'Model A — Baseline\n(Acc: {acc_A*100:.1f}%)', acc_A),
    (axes[1], cm_B, f'Model B — Cải tiến\n(Acc: {acc_B*100:.1f}%)', acc_B)
]:
    sns.heatmap(cm, annot=True, fmt='d', ax=ax,
                xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES,
                cmap='Blues', linewidths=0.3)
    ax.set_title(title, fontsize=13, pad=10)
    ax.set_ylabel('Nhãn thực tế')
    ax.set_xlabel('Nhãn dự đoán')

plt.suptitle('Confusion Matrix: Model A vs Model B', fontsize=15, fontweight='bold')
plt.tight_layout()
plt.savefig('/content/drive/MyDrive/AI/compare_confusion_matrix.png', dpi=120)
plt.show()
print('✅ Đã lưu confusion matrix!')
# Out:
# ✅ Đã lưu confusion matrix!

# %%
# ============================================================
# BƯỚC 4.4 — Biểu đồ cột so sánh F1 từng lớp
#
# Giúp thấy rõ lớp nào Model B cải thiện nhiều nhất
# ============================================================
f1_A = [report_A[cls]['f1-score'] for cls in CLASS_NAMES]
f1_B = [report_B[cls]['f1-score'] for cls in CLASS_NAMES]

x = np.arange(len(CLASS_NAMES))
width = 0.35

fig, ax = plt.subplots(figsize=(18, 6))
bars_A = ax.bar(x - width/2, f1_A, width, label='Model A', color='steelblue', alpha=0.8)
bars_B = ax.bar(x + width/2, f1_B, width, label='Model B', color='coral',     alpha=0.8)

ax.set_xlabel('Ký hiệu tay (Lớp)', fontsize=12)
ax.set_ylabel('F1-score', fontsize=12)
ax.set_title('F1-score từng lớp: Model A vs Model B', fontsize=14)
ax.set_xticks(x)
ax.set_xticklabels(CLASS_NAMES)
ax.legend(fontsize=11)
ax.set_ylim([0, 1.1])
ax.grid(True, axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig('/content/drive/MyDrive/AI/compare_f1_per_class.png', dpi=150)
plt.show()
print('✅ Đã lưu biểu đồ F1 từng lớp!')
# Out:
# ✅ Đã lưu biểu đồ F1 từng lớp!

# %%
# ============================================================
# BƯỚC CUỐI — Kiểm tra tất cả file đã lưu
# ============================================================
output_files = [
    '/content/drive/MyDrive/AI/model_A_final.keras',
    '/content/drive/MyDrive/AI/model_B_final.keras',
    '/content/drive/MyDrive/AI/report_model_A.txt',
    '/content/drive/MyDrive/AI/report_model_B.txt',
    '/content/drive/MyDrive/AI/compare_training_history.png',
    '/content/drive/MyDrive/AI/compare_confusion_matrix.png',
    '/content/drive/MyDrive/AI/compare_f1_per_class.png',
]

print('📦 Kiểm tra file đầu ra:')
for f in output_files:
    exists = os.path.exists(f)
    size   = os.path.getsize(f)/1024 if exists else 0
    status = f'✅ ({size:.0f} KB)' if exists else '❌'
    print(f'  {status} {os.path.basename(f)}')

print('\n🎉 Hoàn thành! Sẵn sàng viết báo cáo Chương 4.')
# Out:
# 📦 Kiểm tra file đầu ra:
#   ✅ (25321 KB) model_A_final.keras
#   ✅ (30710 KB) model_B_final.keras
#   ✅ (2 KB) report_model_A.txt
#   ✅ (2 KB) report_model_B.txt
#   ✅ (73 KB) compare_training_history.png
#   ✅ (144 KB) compare_confusion_matrix.png
#   ✅ (52 KB) compare_f1_per_class.png
#
# 🎉 Hoàn thành! Sẵn sàng viết báo cáo Chương 4.
